# %%
import torch
points = torch.tensor([1.0, 4.0, 2.0, 1.0, 3.0, 5.0])

# %%
points[4]
# Out:
# tensor(3.)

# %% [markdown]
# ## Finding the shape of the tensor, size() function returns the same output

# %%
points.shape
# Out:
# torch.Size([3, 2])

# %%
points.size()
# Out:
# torch.Size([3, 2])

# %% [markdown]
# ## Setting the device on the tensor using the device

# %%
points = torch.tensor([[1.0, 4.0], [2.0, 1.0], [3.0, 5.0]], device='mps')
points.storage()
# Out:
#  1.0
#  4.0
#  2.0
#  1.0
#  3.0
#  5.0
# [torch.storage.TypedStorage(dtype=torch.float32, device=mps:0) of size 6]

# %%
points[0, 1].storage_offset()
# Out:
# 1

# %%
points.stride()
# Out:
# (2, 1)

# %%
points[2].storage_offset()
# Out:
# 4

# %%
points = torch.tensor([[1.0, 2.0], [3.0, 4.0]], dtype=torch.float64)
points
# Out:
# tensor([[1., 2.],
#         [3., 4.]], dtype=torch.float64)

# %%
import torch
print(torch.backends.mps.is_available())   # Should be True for Apple Silicon
# Out:
# True

# %%
# Move an existing tensor to MPS
points = torch.tensor([1.0, 4.0, 2.0, 1.0, 3.0, 5.0])
gpu_points = points.to('mps')

# Or create it directly on MPS
gpu_points = torch.tensor([1.0, 4.0, 2.0, 1.0, 3.0, 5.0], device='mps')

# %%
points = torch.tensor([1.0, 4.0, 2.0, 1.0, 3.0, 5.0])
print(points)
# Out:
# tensor([1., 4., 2., 1., 3., 5.])

# %%
points.stride()
# Out:
# (1,)

# %%
points = torch.tensor([[1.0, 2.0], [3.0, 4.0]], dtype=torch.float64)
print(points)
# Out:
# tensor([[1., 2.],
#         [3., 4.]], dtype=torch.float64)

# %%
points = torch.tensor([[1.0, 2.0], [3.0, 4.0]], device='mps')
print(points)
# Out:
# tensor([[1., 2.],
#         [3., 4.]], device='mps:0')

# %%
torch.__version__
# Out:
# '2.5.1'

# %%
## torch.utils.data

from torch.utils.data import (TensorDataset, DataLoader)

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# Define your training data
x_train = torch.randn(100, 10)   # 100 samples, 10 features
y_train = torch.randint(0, 2, (100,))  # 100 binary labels

train_dataset = TensorDataset(x_train, y_train)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
for x_batch in train_dataloader:
    x_batch, y_batch = batch
    print(x_batch.shape, y_batch.shape)
    break  # Just show the first batch
# Out:
# torch.Size([32, 10]) torch.Size([32])

# %%
x = torch.tensor([[0,0,1],[1,1,1],[0,0,0]])

x
# Out:
# tensor([[0, 0, 1],
#         [1, 1, 1],
#         [0, 0, 0]])

# %%
players = torch.zeros(2, 2)
players
# Out:
# tensor([[0., 0.],
#         [0., 0.]])

# %% [markdown]
# ## Extracting max value in a tensor and the item max value

# %%
pressure = torch.rand(2, 2)
pressure
# Out:
# tensor([[0.7919, 0.6216],
#         [0.7342, 0.3562]])

# %%
pressure.max()
# Out:
# tensor(0.7919)

# %%
pressure.max().item()
# Out:
# 0.7918816208839417

# %% [markdown]
# ## Getting the tensor type and transforming its type using the .to() function.

# %%
output = torch.rand(3, 2)
output
# Out:
# tensor([[0.6809, 0.0713],
#         [0.2389, 0.0932],
#         [0.8179, 0.6074]])

# %%
output.type()
# Out:
# 'torch.FloatTensor'

# %%
result = torch.tensor([[0,0,1],[1,1,1],[0,0,0]]).to(dtype=torch.int64)
result.type()
# Out:
# 'torch.LongTensor'

# %% [markdown]
# ## Transforming a 1D tensor to a different shape using view() or reshape() functions. Reshape is recommended for use.

# %%
mnist_flat = torch.rand(784)
updated = mnist_flat.reshape(1,28,28)
updated.shape
# Out:
# torch.Size([1, 28, 28])
