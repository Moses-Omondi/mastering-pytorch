# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %% [markdown]
# ## Define model architecture.

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.cn1 = nn.Conv2d(1, 16, 3, 1)
        self.cn2 = nn.Conv2d(16, 32, 3, 1)
        self.dp1 = nn.Dropout2d(0.10)
        self.dp2 = nn.Dropout2d(0.25)
        self.fc1 = nn.Linear(4608, 64)
        self.fc2 = nn.Linear(64, 10)
        
    def forward(self, x):
        x = self.cn1(x)
        x = F.relu(x)
        x = self.cn2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dp1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dp2(x)
        x = self.fc2(x)
        op = F.log_softmax(x, dim=1)
        return op

# %% [markdown]
# ## define training and inference routines

# %%
def train(model, device, train_dataloader, optim, epoch):
    model.train()
    for b_i, (X, y) in enumerate(train_dataloader):
        X, y = X.to(device), y.to(device)
        optim.zero_grad()
        pred_prob = model(X)
        loss = F.nll_loss(pred_prob, y)
        loss.backward()
        optim.step()
        if b_i % 10 == 0:
            print('epoch: {} [{}/{} ({:.0f}%)]\t training loss: {:.6f}'.format(
                epoch, 
                b_i * len(X), 
                len(train_dataloader.dataset),
                100. * b_i / len(train_dataloader), 
                loss.item()
                )
            )

# %%
def test(model, device, test_dataloader):
    model.eval()
    loss = 0
    success = 0
    with torch.no_grad():
        for X, y in test_dataloader:
            X, y = X.to(device), y.to(device)
            pred_prob = model(X)
            loss += F.nll_loss(pred_prob, y, reduction='sum').item()
            pred = pred_prob.argmax(dim=1, keepdim = True)
            success += pred.eq(y.view_as(pred)).sum().item()
    loss /= len(test_dataloader.dataset)
    
    print('\nTest dataset: Overall Loss: {:.4f}, Overall Accuracy: {}/{} ({:.0f}%)\n'.format(
        loss, 
        success, 
        len(test_dataloader.dataset),
        100. * success / len(test_dataloader.dataset)
        )
    )

# %% [markdown]
# ## Create data loaders

# %%
train_dataloader = torch.utils.data.DataLoader(
    datasets.MNIST(
        '../data',
        train=True,
        download=True,
        transform=transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1302,), (0.3069))
        ])
    ),
    batch_size=32, shuffle=False
)

test_dataloader = torch.utils.data.DataLoader(
    datasets.MNIST(
        '../data',
        train=False,
        transform=transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1302,), (0.3069,))
        ])        
    ),
    batch_size=500, shuffle=False
)

# %% [markdown]
# ## Define optimizers

# %%
torch.manual_seed(0)
device = torch.device('cpu')

model = ConvNet()
optimizer = optim.Adadelta(model.parameters(), lr=0.5)

# %% [markdown]
# ## Model Training

# %%
for epoch in range(1, 3):
    train(model, device, train_dataloader, optimizer, epoch)
    test(model, device, test_dataloader)
# Out:
# epoch: 1 [0/60000 (0%)]	 training loss: 2.291804
# epoch: 1 [320/60000 (1%)]	 training loss: 1.583885
# epoch: 1 [640/60000 (1%)]	 training loss: 1.175324
# epoch: 1 [960/60000 (2%)]	 training loss: 0.909112
# epoch: 1 [1280/60000 (2%)]	 training loss: 1.041991
# epoch: 1 [1600/60000 (3%)]	 training loss: 0.522899
# epoch: 1 [1920/60000 (3%)]	 training loss: 0.457852
# epoch: 1 [2240/60000 (4%)]	 training loss: 0.230259
# epoch: 2 [48640/60000 (81%)]	 training loss: 0.147609
# epoch: 2 [48960/60000 (82%)]	 training loss: 0.168540
# epoch: 2 [49280/60000 (82%)]	 training loss: 0.007895
# epoch: 2 [49600/60000 (83%)]	 training loss: 0.022782
# epoch: 2 [49920/60000 (83%)]	 training loss: 0.012329
# epoch: 2 [50240/60000 (84%)]	 training loss: 0.009618
# epoch: 2 [50560/60000 (84%)]	 training loss: 0.088873
# epoch: 2 [50880/60000 (85%)]	 training loss: 0.122236
# epoch: 2 [51200/60000 (85%)]	 training loss: 0.064624
# epoch: 2 [51520/60000 (86%)]	 training loss: 0.084494
# epoch: 2 [51840/60000 (86%)]	 training loss: 0.084852
# epoch: 2 [52160/60000 (87%)]	 training loss: 0.037936
# epoch: 2 [52480/60000 (87%)]	 training loss: 0.008218
# epoch: 2 [52800/60000 (88%)]	 training loss: 0.189626
# epoch: 2 [53120/60000 (89%)]	 training loss: 0.003696
# epoch: 2 [53440/60000 (89%)]	 training loss: 0.174244
# epoch: 2 [53760/60000 (90%)]	 training loss: 0.003802
# epoch: 2 [54080/60000 (90%)]	 training loss: 0.043136
# epoch: 2 [54400/60000 (91%)]	 training loss: 0.010301
# epoch: 2 [54720/60000 (91%)]	 training loss: 0.013861
# epoch: 2 [55040/60000 (92%)]	 training loss: 0.040998
# epoch: 2 [55360/60000 (92%)]	 training loss: 0.006313
# epoch: 2 [55680/60000 (93%)]	 training loss: 0.001328
# epoch: 2 [56000/60000 (93%)]	 training loss: 0.015066
# epoch: 2 [56320/60000 (94%)]	 training loss: 0.005520
# epoch: 2 [56640/60000 (94%)]	 training loss: 0.008740
# epoch: 2 [56960/60000 (95%)]	 training loss: 0.016706
# epoch: 2 [57280/60000 (95%)]	 training loss: 0.113368
# epoch: 2 [57600/60000 (96%)]	 training loss: 0.099923
# epoch: 2 [57920/60000 (97%)]	 training loss: 0.003882
# epoch: 2 [58240/60000 (97%)]	 training loss: 0.144371
# epoch: 2 [58560/60000 (98%)]	 training loss: 0.000669
# epoch: 2 [58880/60000 (98%)]	 training loss: 0.000947
# epoch: 2 [59200/60000 (99%)]	 training loss: 0.001650
# epoch: 2 [59520/60000 (99%)]	 training loss: 0.000942
# epoch: 2 [59840/60000 (100%)]	 training loss: 0.001177
#
# Test dataset: Overall Loss: 0.0397, Overall Accuracy: 9870/10000 (99%)

# %% [markdown]
# ## Run inference

# %%
test_samples = enumerate(test_dataloader)
b_i, (sample_data, sample_targets) = next(test_samples)
plt.imshow(sample_data[0][2], cmap='gray', interpolation='none')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[53], line 3
#       1 test_samples = enumerate(test_dataloader)
#       2 b_i, (sample_data, sample_targets) = next(test_samples)
# ----> 3 plt.imshow(sample_data[0][2], cmap='gray', interpolation='none')
#       4 plt.show()
#
# IndexError: index 2 is out of bounds for dimension 0 with size 1

# %%
print(f"Model prediction is: {model(sample_data).data.max(1)[1][0]}")
print(f"Ground truth is: {sample_targets[0]}")
# Out:
# Model prediction is: 7
# Ground truth is: 7
